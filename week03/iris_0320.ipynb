# %% [markdown]
# #week03 / iris

# %% [markdown]
# 컴퓨터공학과 / 202433638 / 장영환

# %%
#붓꽃 데이터 set 가져오기
from sklearn import datasets
data = datasets.load_iris()
#data #확인용

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

x = data.data
y = data.target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)
#훈련데이터, 테스트데이터 세팅
print(x_train.shape)
print(x_test.shape)
# Out:
# (120, 4)
# (30, 4)

# %% [markdown]
# #Logistic Regression Classifier

# %%
from sklearn.linear_model import LogisticRegression

clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(x_train, y_train)
pred_lr = clf_lr.predict(x_test)


print (accuracy_score(y_test, pred_lr))
print("")
print (confusion_matrix(y_test, pred_lr))
# Out:
# 0.9666666666666667
#
# [[16  0  0]
#  [ 0  4  1]
#  [ 0  0  9]]

# %% [markdown]
# #DecisionTree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(x_train, y_train)

pred_dt = clf_dt.predict(x_test)

print (accuracy_score(y_test, pred_dt))
print("")
print (confusion_matrix(y_test, pred_dt))
# Out:
# 0.9666666666666667
#
# [[16  0  0]
#  [ 0  4  1]
#  [ 0  0  9]]

# %% [markdown]
# #RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(x_train, y_train)

pred = rf_clf.predict(x_test)

print(accuracy_score(y_test,pred))
print("")
print (confusion_matrix(y_test, pred))
# Out:
# 0.9666666666666667
# [[16  0  0]
#  [ 0  4  1]
#  [ 0  0  9]]

# %% [markdown]
# #KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(x_train, y_train)

y_pred = knn.predict(x_test)
from sklearn import metrics
scores = metrics.accuracy_score(y_test, y_pred)
print(scores)
# Out:
# 0.9666666666666667

# %% [markdown]
# #Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
#forRegression
data2=data.data # data에서 target값 제외하고

y = data2[:, 0] # y값으로 1열(index)
x = data2[:, 1:] # 1열을 제외한 나머지(index)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

model = LinearRegression()
model.fit(x_train, y_train)
ly_preds = model.predict(x_test)

print('평균제곱오차', mean_squared_error(ly_preds, y_test))
# 평균제곱오차 말그대로 오차**2의 평균값 회귀는 연속적인 값임으로 정확도로 측정 불가
#얼마나 적게 틀렸는지를 확인하기 위한 오차 측정을 위한 지표 MSE, 일반적으로 0에 가까울수록좋다
# Out:
# 평균제곱오차 0.08345256308014323
